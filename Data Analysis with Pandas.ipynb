# %% [markdown]
# <a href="https://colab.research.google.com/github/WanjohiChristopher/Intro-to-Machine-Learning-DSCJKUAT/blob/master/Data%20Analysis%20with%20Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas
# The Pandas library is built on NumPy and provides easy-to-use data
# structures and data analysis tools for the Python programming language.
#
# is also Python library used for working with data sets. It has functions for analyzing, cleaning, exploring, and manipulating data. The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008.

# %% [markdown]
# ## Core components of pandas: Series and DataFrames
#
# The primary two components of pandas are : the Series and DataFrame.
#
# A Series is essentially a column,
#
# A DataFrame is a multi-dimensional table made up of a collection of Series.

# %%
import pandas as pd
#creating a dictionary{key:values}
data = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2],
    "Mangoes":[6,7,10,3]
}

# %%
#pass the data variable to the  pandas DataFrame constructor
df=pd.DataFrame(data)
#viewing the data
df.head()
# Out:
#    apples  oranges  Mangoes
# 0       3        0        6
# 1       2        3        7
# 2       0        7       10
# 3       1        2        3

# %%
# create index column by yourself
purchases = pd.DataFrame(data, index=['James', 'Robert', 'Lily', 'Mary'])

purchases
# Out:
#         apples  oranges  Mangoes
# James        3        0        6
# Robert       2        3        7
# Lily         0        7       10
# Mary         1        2        3

# %%
#we can use loc in pandas to acces individual person details
purchases.loc['Robert']
# Out:
# apples     2
# oranges    3
# Mangoes    7
# Name: Robert, dtype: int64

# %%
# we can also set index to be apples for example
df = purchases.set_index('apples')

df
# Out:
#         oranges  Mangoes
# apples
# 3             0        6
# 2             3        7
# 0             7       10
# 1             2        3

# %%
#drop values from a row(axis=0)
df.drop([3,1],axis=0,inplace=True)

df
# Out:
#         oranges  Mangoes
# apples
# 2             3        7
# 0             7       10

# %%
#dropping columns axis=1
df.drop('oranges', axis=1,inplace=True)
df
# Out:
#         Mangoes
# apples
# 2             7
# 0            10

# %%
df=df.rank()
df
# Out:
#         Mangoes
# apples
# 2           1.0
# 0           2.0

# %%
puchases=purchases.sort_values(by='oranges')
purchases
# Out:
#         apples  oranges  Mangoes
# James        3        0        6
# Robert       2        3        7
# Lily         0        7       10
# Mary         1        2        3

# %%
#reading data using pandas
#link to dataset http://bit.ly/WorldPopulationDataset1
#reading excel file

world_pop=pd.read_excel("http://bit.ly/WorldPopulationDataset1")
world_pop.head(10)
# Out:
#    Rank                   Country  Population         Year
# 0     1                     China  1380914176  2019 (Est.)
# 1     2                     India  1311559168  2019 (Est.)
# 2     3  United States of America   333928672  2019 (Est.)
# 3     4                 Indonesia   265253184  2019 (Est.)
# 4     5                    Brazil   220632960  2019 (Est.)
# 5     6                  Pakistan   210797840  2019 (Est.)
# 6     7                   Nigeria   202670592  2019 (Est.)
# 7     8                Bangladesh   180203952  2019 (Est.)
# 8     9                    Russia   133026408  2019 (Est.)
# 9    10                     Japan   125853032  2019 (Est.)

# %%
#reading csvs(comma separated values) 
Diabetes_df=pd.read_csv('http://bit.ly/AtaraaDiabetesDataset1')
Diabetes_df.sample(4)
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 669            9      154  ...   45        0
# 249            1      111  ...   23        0
# 405            2      123  ...   26        0
# 662            8      167  ...   43        1
#
# [4 rows x 9 columns]

# %%
##incase of reading json 
#use pd.read_json("")

# %% [markdown]
# ## Selecting, Boolean Indexing & Setting

# %% [markdown]
# Selecing by position

# %%
#selecting single value by row and column
world_pop.iloc[1,2]
# Out:
# 1311559168

# %% [markdown]
# Selecting by  label

# %%
print('The Country for index 5 is' +  world_pop.loc[5,['Country']])
# Out:
# Country    The Country for index 5 isPakistan
# Name: 5, dtype: object

# %% [markdown]
# ## Setting

# %%
world_pop['Rank']='Rankings'
world_pop
# Out:
#          Rank                    Country  Population         Year
# 0    Rankings                      China  1380914176  2019 (Est.)
# 1    Rankings                      India  1311559168  2019 (Est.)
# 2    Rankings   United States of America   333928672  2019 (Est.)
# 3    Rankings                  Indonesia   265253184  2019 (Est.)
# 4    Rankings                     Brazil   220632960  2019 (Est.)
# ..        ...                        ...         ...          ...
# 223  Rankings               Cook Islands        8799  2019 (Est.)
# 224  Rankings               Saint Helena        7852  2019 (Est.)
# 225  Rankings           Saint Barthélemy        7140  2019 (Est.)
# 226  Rankings  Saint Pierre and Miquelon        5409  2019 (Est.)
# 227  Rankings                 Montserrat        5342  2019 (Est.)
#
# [228 rows x 4 columns]

# %% [markdown]
# Boolen Indexing

# %%
world_pop[world_pop['Population']>1200000000]
# Out:
#        Rank Country  Population         Year
# 0  Rankings   China  1380914176  2019 (Est.)
# 1  Rankings   India  1311559168  2019 (Est.)

# %% [markdown]
# ### Common Pandas Data Analysis functions

# %% [markdown]
# Data Acquisition

# %%
#read dataset
shopify=pd.read_csv("https://bit.ly/ShoprityDS")
#checing the first 5 rows
shopify.head()
# Out:
#   Item_Identifier  Item_Weight  ... Outlet_Location_Type  Item_Outlet_Sales
# 0           FDA15         9.30  ...               Tier 1          3735.1380
# 1           DRC01         5.92  ...               Tier 3           443.4228
# 2           FDN15        17.50  ...               Tier 1          2097.2700
# 3           FDX07        19.20  ...               Tier 3           732.3800
# 4           NCD19         8.93  ...               Tier 3           994.7052
#
# [5 rows x 11 columns]

# %%
#checing the last 5 rows
shopify.tail()
# Out:
#      Item_Identifier  Item_Weight  ... Outlet_Location_Type  Item_Outlet_Sales
# 8524           FDF22        6.865  ...               Tier 3          2778.3834
# 8525           FDS36        8.380  ...               Tier 2           549.2850
# 8526           NCJ29       10.600  ...               Tier 2          1193.1136
# 8527           FDN46        7.210  ...               Tier 3          1845.5976
# 8528           DRG01       14.800  ...               Tier 1           765.6700
#
# [5 rows x 11 columns]

# %%
#checing the records in the dataset

print('The no of rows in the dataset  is:\n ',shopify.shape[0])

print('The no of columns in the dataset is:\n ',shopify.shape[1])
# Out:
# The no of rows in the dataset  is:
#   8529
# The no of columns in the dataset is:
#   11

# %%
#checking information about our dataset(column names ,missing,values ,datatypes etc)
shopify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8529 entries, 0 to 8528
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8529 non-null   object
#  1   Item_Weight                7066 non-null   float64
#  2   Item_Fat_Content           8529 non-null   object
#  3   Item_Visibility            8528 non-null   float64
#  4   Item_Type                  8529 non-null   object
#  5   Item_MRP                   8527 non-null   float64
#  6   Outlet_Identifier          8529 non-null   object
#  7   Outlet_Establishment_Year  8529 non-null   int64
#  8   Outlet_Size                6118 non-null   object
#  9   Outlet_Location_Type       8529 non-null   object
#  10  Item_Outlet_Sales          8529 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 733.1+ KB

# %%
#checking column names
print("These are the columns \n" ,shopify.columns)
# Out:
# These are the columns
#  Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Item_Outlet_Sales'],
#       dtype='object')

# %%
#checking column datatypes

print("These are the datatypes \n" ,shopify.dtypes)
# Out:
# These are the datatypes
#  Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Item_Outlet_Sales            float64
# dtype: object

# %%
### Selecting itemtypes with only low fat content from the dataset
shopify['Item_Type'][shopify['Item_Fat_Content']=='Low Fat']
# Out:
# 0                       Dairy
# 2                        Meat
# 4                   Household
# 8                 Snack Foods
# 11      Fruits and Vegetables
#                 ...
# 8521             Baking Goods
# 8522                   Others
# 8524              Snack Foods
# 8526       Health and Hygiene
# 8528              Soft Drinks
# Name: Item_Type, Length: 5092, dtype: object

# %%
### Selecting itemtypes with only regular content from the dataset
shopify['Item_Type'][shopify['Item_Fat_Content']=='Regular']
# Out:
# 1                 Soft Drinks
# 3       Fruits and Vegetables
# 5                Baking Goods
# 6                 Snack Foods
# 7                 Snack Foods
#                 ...
# 8516              Snack Foods
# 8519                     Meat
# 8520                   Canned
# 8525             Baking Goods
# 8527              Snack Foods
# Name: Item_Type, Length: 2892, dtype: object

# %%
shopify[shopify['Item_Outlet_Sales']>2000].head(3)
# Out:
#   Item_Identifier  Item_Weight  ... Outlet_Location_Type  Item_Outlet_Sales
# 0           FDA15          9.3  ...               Tier 1          3735.1380
# 2           FDN15         17.5  ...               Tier 1          2097.2700
# 8           FDP10          NaN  ...               Tier 3          4022.7636
#
# [3 rows x 11 columns]

# %%
## Checking For Duplicates
shopify.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 1
# Item_Type                       0
# Item_MRP                        2
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2411
# Outlet_Location_Type            0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# We have missing values in our dataset including Item weight column etc.

# %% [markdown]
# ## Pivot Tables
#     A pivot table is a similar operation that is commonly seen in spreadsheets and other programs that operate on tabular data. The pivot table takes simple column-wise data as input, and groups the entries into a two-dimensional table that provides a multidimensional summarization of the data.
#
#     A Pivot Table is used to summarise, sort, reorganise, group, count, total or average data stored in a table. It allows us to transform columns into rows and rows into columns. It allows grouping by any field (column), and using advanced calculations on them.
#
#     pandas.pivot_table(data, values=None, index=None, columns=None, aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All', observed=False)[source]¶ Create a spreadsheet-style pivot table as a DataFrame.
#
#     The levels in the pivot table will be stored in MultiIndex objects (hierarchical indexes) on the index and columns of the result DataFrame.

# %%
# Applying multiple aggregate functions to a group

pd.pivot_table(shopify, index=['Item_Type', 'Item_Fat_Content'], aggfunc={'Item_Outlet_Sales': sum}).head(20)
# Out:
#                                Item_Outlet_Sales
# Item_Type    Item_Fat_Content
# Baking Goods LF                       33415.8362
#              Low Fat                 536343.1796
#              Regular                 673368.8144
#              low fat                  10764.6544
#              reg                      14163.5634
# Breads       LF                       13580.3226
#              Low Fat                 284773.3128
#              Regular                 244648.2100
#              low fat                   7327.1290
#              reg                       2908.2144
# Breakfast    LF                        1635.2048
#              Low Fat                  97806.6858
#              Regular                 129024.7162
#              reg                       3832.3448
# Canned       LF                       28011.5376
#              Low Fat                 700572.7366
#              Regular                 668952.5630
# ...

# %%
#checking for duplicates in our dataset
shopify.duplicated().any()
# Out:
# True

# %% [markdown]
# True Means we have duplicates during data cleaning we will drop them

# %% [markdown]
# ### Data Cleaning /Data Wrangling

# %% [markdown]
# # Removing null values
#
# Data Scientists and Analysts regularly face the dilemma of dropping or imputing null values, and is a decision that requires intimate knowledge of your data and its context. Overall, removing null data is only suggested if you have a small amount of missing data.

# %%
import missingno as msno

# Gives a bar chart of the missing values
msno.bar(shopify)

# %%
msno.heatmap(shopify, cmap='YlGnBu')

# %%
msno.dendrogram(shopify)
# Out:
# /usr/local/lib/python3.7/dist-packages/scipy/cluster/hierarchy.py:2837: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   ax.set_ylim([dvw, 0])

# %%
#dropping misssing values
# shopify.dropna()

# %%
#filling missing values with either mean,mode,median
shopify['Item_Weight'].fillna(shopify['Item_Weight'].mean(),inplace=True)

# %%
shopify['Outlet_Size'].fillna(shopify['Outlet_Size'].mode()[0],inplace=True)

# %%
shopify['Item_Visibility'].fillna(shopify['Item_Visibility'].median(),inplace=True)

# %%
#using foward filling
shopify['Item_MRP'].fillna(method='ffill', inplace=True)

# %%
# using backward filling
# shopify['Item_MRP '].fillna(method='bfill', inplace=True)

# %% [markdown]
# Dealing With Duplicates in your Dataset

# %%
#we consider dropping duplicate
shopify.drop_duplicates(inplace=True)
